# %% [markdown]
# ### Import libraries and extract information from Wikipedia.

# %%
#Import libraries
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup 

#Wikipedia's URL, connect to the page and get data
URL = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
r = requests.get(URL) 

#Read content
soup = BeautifulSoup(r.content, 'html5lib') 

#Find table with information
table = soup.find('table', attrs = {'class':'wikitable sortable'}) 

#Create an empty list to put data
my_list = []
#Go through table rows and extract text from columns and add into my_list
for idx, row in enumerate(table.findAll('td')):
    x  = row.text
    x = x.replace('\n','')
    my_list.append(x)

#Create chunks fuction to split list into different lists
def chunks(l, n):
    for i in range(0, len(l), n):
        yield l[i:i + n]

#Headers of data frame
header = ['Postcode','Borough', 'Neighbourhood']
#Data of dataframe
data = list(chunks(my_list,3))

#Finally, create my dataframe with table data
df = pd.DataFrame(data,columns=header)

#Remove Not assigned cells
df = df[df['Borough'] != 'Not assigned']
#Group cells by Postcode and Borough and group neighbourhoods using ', ' as delimiter
df = df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(lambda x: ', '.join(x.dropna().unique())).reset_index()
#Find not assigned neighourhoods and if that's the case use the Borough name, otherwise keep the neighbourhood value
df['Neighbourhood'] = np.where(df['Neighbourhood'] == 'Not assigned', df['Borough'],df['Neighbourhood'])

#Shape
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Merge Wikipedia's data with Location of Neighboors

# %%
#Import data
path  = 'C:\\Users\\renon\\Downloads\\Geospatial_Coordinates.csv'
geo_data = pd.read_csv(path)

#Merge
df = pd.merge(df,geo_data,left_on='Postcode', right_on='Postal Code', how='left')
df = df[['Postcode', 'Borough', 'Neighbourhood', 'Latitude','Longitude']]
df.columns = ['Postal Code', 'Borough', 'Neighbourhood', 'Latitude','Longitude']

# %% [markdown]
# ### Create Connection with Foursquare to pull information using the API

# %%
#My User ID
CLIENT_ID = 'UOYNHZFOHY5ETVSAPG4NKSH20V3PPSFSZCCRLLT02BRLDUU1' # your Foursquare ID
CLIENT_SECRET = 'OTGN5Q4YMFVIQR3XCV3K4XLJ3H1HFYLIJZJALDVYRGGF3AWK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100
radius = 500

# %% [markdown]
# ### Create function to retrieve information using the parameters above. The function will get nearby values based on the Latitude and Longitude of the Neighboors.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### I'm going to fitler my data frame to keep only Boroughs which contains the word 'Toronto'.

# %%
#Create toronto df
toronto_df = df[df['Borough'].str.contains("Toronto")]

# type your answer here
toronto_venues = getNearbyVenues(names=toronto_df['Neighbourhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity
# Brockton, Exhibition Place, Parkdale Village
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Business Reply Mail Processing Centre 969 Eastern

# %% [markdown]
# ### Create data frame to run KMeans and perform a Clustering Analysis

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2       Brockton, Exhibition Place, Parkdale Village           Yoga Studio
# 3  Business Reply Mail Processing Centre 969 Eastern           Yoga Studio
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...       Airport Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café            Steakhouse                   Bar
# 1          Cocktail Bar                Bakery        Farmers Market
# 2        Breakfast Spot                  Café           Coffee Shop
# 3         Auto Workshop            Smoke Shop            Skate Park
# 4        Airport Lounge      Airport Terminal                   Bar
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   American Restaurant       Thai Restaurant                   Gym
# 1              Beer Bar            Steakhouse           Cheese Shop
# 2                Bakery               Stadium         Burrito Place
# 3               Brewery         Burrito Place               Butcher
# 4              Boutique               Airport    Airport Food Court
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Sushi Restaurant                Bakery             Restaurant
# 1                  Café    Seafood Restaurant     Basketball Stadium
# 2            Restaurant  Caribbean Restaurant           Climbing Gym
# 3            Restaurant      Recording Studio                   Park
# 4          Airport Gate         Boat or Ferry        Harbor / Marina

# %% [markdown]
# ### Next I'm going to run a clustering analysis using KMeans, the number of clusters will be 5. Basically the algorithm will start grouping neighboors based on the Category of the venues.

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_venues

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  The Beaches              43.676357              -79.293031
# 1  The Beaches              43.676357              -79.293031
# 2  The Beaches              43.676357              -79.293031
# 3  The Beaches              43.676357              -79.293031
# 4  The Beaches              43.676357              -79.293031
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# 0                   Glen Manor Ravine       43.676821       -79.293942
# 1  The Big Carrot Natural Food Market       43.678879       -79.297734
# 2                 Grover Pub and Grub       43.679181       -79.297215
# 3                 Glen Stewart Ravine       43.676300       -79.294784
# 4                       Upper Beaches       43.680563       -79.292869
#
#          Venue Category  Cluster Labels 1st Most Common Venue  \
# 0                 Trail               2     Health Food Store
# 1     Health Food Store               2     Health Food Store
# 2                   Pub               2     Health Food Store
# 3  Other Great Outdoors               2     Health Food Store
# 4          Neighborhood               2     Health Food Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Other Great Outdoors                 Trail                   Pub
# 1  Other Great Outdoors                 Trail                   Pub
# 2  Other Great Outdoors                 Trail                   Pub
# 3  Other Great Outdoors                 Trail                   Pub
# 4  Other Great Outdoors                 Trail                   Pub
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Wings Joint            Donut Shop        Discount Store
# 1           Wings Joint            Donut Shop        Discount Store
# 2           Wings Joint            Donut Shop        Discount Store
# 3           Wings Joint            Donut Shop        Discount Store
# 4           Wings Joint            Donut Shop        Discount Store
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0              Dive Bar               Dog Run       Doner Restaurant
# 1              Dive Bar               Dog Run       Doner Restaurant
# 2              Dive Bar               Dog Run       Doner Restaurant
# 3              Dive Bar               Dog Run       Doner Restaurant
# 4              Dive Bar               Dog Run       Doner Restaurant

# %% [markdown]
# ### Next, I'm going to plot the results in a map so we can see how the clusters are distributed.

# %%
import folium
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[43.676357, -79.293031], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Neighborhood Latitude'], toronto_merged['Neighborhood Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analyze Clusters

# %%
df_analyze = toronto_merged[['Neighborhood', 'Cluster Labels', '1st Most Common Venue', '2nd Most Common Venue',
       '3rd Most Common Venue', '4th Most Common Venue',
       '5th Most Common Venue', '6th Most Common Venue',
       '7th Most Common Venue', '8th Most Common Venue',
       '9th Most Common Venue', '10th Most Common Venue']].drop_duplicates()

df_analyze[df_analyze['Cluster Labels'] == 0]
# Out:
#                     Neighborhood  Cluster Labels 1st Most Common Venue  \
# 175  Moore Park, Summerhill East               0            Playground
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 175            Restaurant    Dim Sum Restaurant    Falafel Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 175           Event Space  Ethiopian Restaurant     Electronics Store
#
#            8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 175  Eastern European Restaurant   Dumpling Restaurant             Donut Shop

# %%
df_analyze[df_analyze['Cluster Labels'] == 1]
# Out:
#                              Neighborhood  Cluster Labels  \
# 46         The Beaches West, India Bazaar               1
# 114                      Davisville North               1
# 192                              Rosedale               1
# 1127  Forest Hill North, Forest Hill West               1
#
#      1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 46                    Park        Sandwich Place            Board Shop
# 114                    Gym        Clothing Store        Breakfast Spot
# 192                   Park            Playground                 Trail
# 1127              Bus Line      Sushi Restaurant                  Park
#
#      4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 46                     Pub          Liquor Store          Burger Joint
# 114      Food & Drink Shop        Sandwich Place                 Hotel
# 192               Building    Dim Sum Restaurant           Event Space
# 1127         Jewelry Store                 Trail      Doner Restaurant
#
#      7th Most Common Venue 8th Most Common Venue        9th Most Common Venue  \
# 46           Burrito Place  Fast Food Restaurant            Fish & Chips Shop
# 114       Asian Restaurant                  Park                Grocery Store
# 192   Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 1127        Discount Store              Dive Bar                      Dog Run
#
#      10th Most Common Venue
# 46               Steakhouse
# 114             Pizza Place
# 192     Dumpling Restaurant
# 1127            Wings Joint

# %%
df_analyze[df_analyze['Cluster Labels'] == 2]
# Out:
#                                            Neighborhood  Cluster Labels  \
# 0                                           The Beaches               2
# 5                          The Danforth West, Riverdale               2
# 69                                      Studio District               2
# 124                                  North Toronto West               2
# 143                                          Davisville               2
# 177   Deer Park, Forest Hill SE, Rathnelly, South Hi...               2
# 197                         Cabbagetown, St. James Town               2
# 242                                Church and Wellesley               2
# 330                           Harbourfront, Regent Park               2
# 379                            Ryerson, Garden District               2
# 479                                      St. James Town               2
# 579                                         Berczy Park               2
# 636                                  Central Bay Street               2
# 725                            Adelaide, King, Richmond               2
# 825   Harbourfront East, Toronto Islands, Union Station               2
# 925            Design Exchange, Toronto Dominion Centre               2
# 1025                     Commerce Court, Victoria Hotel               2
# 1132                The Annex, North Midtown, Yorkville               2
# 1155                     Harbord, University of Toronto               2
# 1190          Chinatown, Grange Park, Kensington Market               2
# 1290  CN Tower, Bathurst Quay, Island airport, Harbo...               2
# 1306                    Stn A PO Boxes 25 The Esplanade               2
# 1403             First Canadian Place, Underground city               2
# 1503                                           Christie               2
# 1519                       Dovercourt Village, Dufferin               2
# 1540                           Little Portugal, Trinity               2
# 1604       Brockton, Exhibition Place, Parkdale Village               2
# 1631                      High Park, The Junction South               2
# 1654                             Parkdale, Roncesvalles               2
# 1669                                 Runnymede, Swansea               2
# 1709  Business Reply Mail Processing Centre 969 Eastern               2
#
#      1st Most Common Venue          2nd Most Common Venue  \
# 0        Health Food Store           Other Great Outdoors
# 5         Greek Restaurant                    Coffee Shop
# 69                    Café                    Coffee Shop
# 124         Clothing Store                    Coffee Shop
# 143           Dessert Shop                 Sandwich Place
# 177            Coffee Shop                            Pub
# 197            Coffee Shop                         Bakery
# 242            Coffee Shop            Japanese Restaurant
# 330            Coffee Shop                         Bakery
# 379            Coffee Shop                 Clothing Store
# 479            Coffee Shop                          Hotel
# 579            Coffee Shop                   Cocktail Bar
# 636            Coffee Shop                           Café
# 725            Coffee Shop                           Café
# 825            Coffee Shop                       Aquarium
# 925            Coffee Shop                           Café
# 1025           Coffee Shop                          Hotel
# 1132           Coffee Shop                           Café
# 1155                  Café                     Restaurant
# 1190                  Café  Vegetarian / Vegan Restaurant
# 1290       Airport Service                 Airport Lounge
# 1306           Coffee Shop                           Café
# 1403           Coffee Shop                           Café
# 1503         Grocery Store                           Café
# 1519           Supermarket                       Pharmacy
# 1540                   Bar                    Coffee Shop
# 1604           Yoga Studio                 Breakfast Spot
# 1631                   Bar                           Café
# 1654        Breakfast Spot                      Gift Shop
# 1669                  Café                    Pizza Place
# 1709           Yoga Studio                  Auto Workshop
#
#         3rd Most Common Venue 4th Most Common Venue  \
# 0                       Trail                   Pub
# 5          Italian Restaurant        Ice Cream Shop
# 69         Italian Restaurant             Gastropub
# 124   Health & Beauty Service   Sporting Goods Shop
# 143               Pizza Place    Italian Restaurant
# 177               Pizza Place   American Restaurant
# 197                      Café           Pizza Place
# 242                   Gay Bar      Sushi Restaurant
# 330                       Pub                  Park
# 379            Cosmetics Shop                  Café
# 479                Restaurant                  Café
# 579                    Bakery        Farmers Market
# 636            Ice Cream Shop    Italian Restaurant
# 725                Steakhouse                   Bar
# 825                     Hotel                  Café
# 925                     Hotel            Restaurant
# 1025                     Café   American Restaurant
# 1132           Sandwich Place           Pizza Place
# 1155      Japanese Restaurant                   Bar
# 1190    Vietnamese Restaurant                   Bar
# 1290         Airport Terminal                   Bar
# 1306               Restaurant  Fast Food Restaurant
# 1403               Steakhouse                 Hotel
# 1503                     Park            Baby Store
# 1519                   Bakery  Fast Food Restaurant
# 1540         Asian Restaurant          Cocktail Bar
# 1604                     Café           Coffee Shop
# 1631       Mexican Restaurant                 Diner
# 1654       Italian Restaurant                   Bar
# 1669              Coffee Shop    Italian Restaurant
# 1709               Smoke Shop            Skate Park
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                   Wings Joint            Donut Shop        Discount Store
# 5        Furniture / Home Store          Liquor Store                Bakery
# 69          American Restaurant                Bakery           Yoga Studio
# 124          Chinese Restaurant          Dessert Shop                 Diner
# 143            Sushi Restaurant           Coffee Shop                  Café
# 177          Light Rail Station            Sports Bar            Bagel Shop
# 197                  Restaurant                Market    Italian Restaurant
# 242                  Restaurant                   Pub           Men's Store
# 330              Breakfast Spot    Mexican Restaurant               Theater
# 379   Middle Eastern Restaurant  Fast Food Restaurant                 Diner
# 479              Cosmetics Shop        Breakfast Spot                Bakery
# 579                    Beer Bar            Steakhouse           Cheese Shop
# 636          Chinese Restaurant          Burger Joint        Sandwich Place
# 725         American Restaurant       Thai Restaurant                   Gym
# 825          Italian Restaurant        Scenic Lookout                Bakery
# 925          Italian Restaurant                   Bar                   Gym
# 1025                 Restaurant    Seafood Restaurant            Steakhouse
# 1132                   Pharmacy     Indian Restaurant        Cosmetics Shop
# 1155                  Bookstore                Bakery    Chinese Restaurant
# 1190         Mexican Restaurant                Bakery    Chinese Restaurant
# 1290                   Boutique               Airport    Airport Food Court
# 1306                     Bakery          Cocktail Bar    Seafood Restaurant
# 1403                 Restaurant                Bakery             Gastropub
# 1503          Convenience Store    Italian Restaurant           Coffee Shop
# 1519      Portuguese Restaurant           Music Venue        Discount Store
# 1540                 Restaurant                  Café                Bakery
# 1604                     Bakery               Stadium         Burrito Place
# 1631  Cajun / Creole Restaurant    Italian Restaurant    Miscellaneous Shop
# 1654                    Dog Run             Bookstore            Restaurant
# 1669                  Bookstore              Tea Room      Sushi Restaurant
# 1709                    Brewery         Burrito Place               Butcher
#
#           8th Most Common Venue    9th Most Common Venue  \
# 0                      Dive Bar                  Dog Run
# 5                    Sports Bar                      Spa
# 69                          Bar              Fish Market
# 124        Fast Food Restaurant       Italian Restaurant
# 143                Gourmet Shop           Farmers Market
# 177                  Restaurant              Supermarket
# 197                   Pet Store                      Pub
# 242    Mediterranean Restaurant                    Hotel
# 330                  Restaurant     Gym / Fitness Center
# 379                       Plaza              Pizza Place
# 479                   Gastropub       Italian Restaurant
# 579                        Café       Seafood Restaurant
# 636                 Salad Place        Indian Restaurant
# 725            Sushi Restaurant                   Bakery
# 825         Sporting Goods Shop                  Brewery
# 925               Deli / Bodega      American Restaurant
# 1025                        Gym                Gastropub
# 1132                        Pub             Burger Joint
# 1155               Dessert Shop            Poutine Place
# 1190        Dumpling Restaurant              Coffee Shop
# 1290               Airport Gate            Boat or Ferry
# 1306                   Beer Bar                    Hotel
# 1403                        Bar                      Gym
# 1503         Athletics & Sports                    Diner
# 1519  Middle Eastern Restaurant                     Café
# 1540                Pizza Place  New American Restaurant
# 1604                 Restaurant     Caribbean Restaurant
# 1631                  Speakeasy      Fried Chicken Joint
# 1654                       Bank             Dessert Shop
# 1669                Post Office                      Spa
# 1709                 Restaurant         Recording Studio
#
#        10th Most Common Venue
# 0            Doner Restaurant
# 5                   Juice Bar
# 69            Coworking Space
# 124        Mexican Restaurant
# 143                Restaurant
# 177          Sushi Restaurant
# 197                      Bank
# 242                       Gym
# 330                      Café
# 379          Ramen Restaurant
# 479                  Creperie
# 579        Basketball Stadium
# 636                       Spa
# 725                Restaurant
# 825               Pizza Place
# 925                 Gastropub
# 1025            Deli / Bodega
# 1132             Liquor Store
# 1155                      Pub
# 1190  Comfort Food Restaurant
# 1290          Harbor / Marina
# 1306           Breakfast Spot
# 1403         Asian Restaurant
# 1503               Restaurant
# 1519                  Brewery
# 1540              Men's Store
# 1604             Climbing Gym
# 1631      Arts & Crafts Store
# 1654            Movie Theater
# 1669                      Bar
# 1709                     Park

# %%
df_analyze[df_analyze['Cluster Labels'] == 3]
# Out:
#       Neighborhood  Cluster Labels 1st Most Common Venue  \
# 110  Lawrence Park               3  Gym / Fitness Center
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 110                  Park           Swim School              Bus Line
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 110                 Diner    Falafel Restaurant           Event Space
#
#     8th Most Common Venue 9th Most Common Venue       10th Most Common Venue
# 110  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant

# %%
df_analyze[df_analyze['Cluster Labels'] == 4]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1125     Roselawn               4                Garden          Home Service
#
#      3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1125    Dim Sum Restaurant    Falafel Restaurant           Event Space
#
#      6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 1125  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
#
#      9th Most Common Venue 10th Most Common Venue
# 1125   Dumpling Restaurant             Donut Shop

# %% [markdown]
# ## Clusters:
# - 0: Close to a Playground and several restaurants.
# - 1: Close to Parks, Stores and some restaurants.
# - 2: Close to several Coffe Shops, Bars and restaurants.
# - 3: Close to Gym, Park and Swim school.
# - 4: CLose to a Garden and restaurants.
